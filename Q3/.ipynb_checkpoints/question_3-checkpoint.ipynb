# %%
import numpy as np
import pandas as pd
import torch
from torch.autograd import Variable
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader, TensorDataset

train_data = np.loadtxt('train_data.txt', dtype=np.float32, delimiter='	',skiprows=1)
print(train_data.shape)
train_truth= np.loadtxt('train_truth.txt', dtype=np.float32, delimiter='	',skiprows=1)
test_data = np.loadtxt('test_data.txt', dtype=np.float32, delimiter='	',skiprows=1)

train_data = torch.from_numpy(train_data)
train_truth = torch.from_numpy(train_truth)
# x , y =(Variable(train_data),Variable(train_truth))

deal_dataset = TensorDataset(train_data, train_truth)
train_loader = DataLoader(dataset=deal_dataset, batch_size=100, shuffle=True, num_workers=2)
test_data = torch.from_numpy(test_data)
#test_predict = torch.from_numpy(test_predict)
testx = Variable(test_data)

class simpleNet(nn.Module):
    def __init__(self,n_input,n_hidden,n_output):
        super(simpleNet,self).__init__()
        self.hidden1 = nn.Linear(n_input,n_hidden)
        self.hidden2 = nn.Linear(n_hidden,n_hidden)
        self.predict = nn.Linear(n_hidden,n_output)
    def forward(self,input):
        out = self.hidden1(input)
        out = F.relu(out)
        out = self.hidden2(out)
        out = F.relu(out)
        out =self.predict(out)

        return out


if __name__ == '__main__':
    spNet = simpleNet(3, 4, 1)
    optimizer = torch.optim.Adam(spNet.parameters(),lr = 1e-4)
    loss_func = torch.nn.MSELoss()
    device = torch.device('cpu')
    losslist = []
    for epoch in range(100):
        for i, data in enumerate(train_loader):
            inputs, labels = data
            inputs, labels = Variable(inputs), Variable(labels)
            y = spNet(inputs)
            # print(y.shape)
            # print(labels.shape)
            loss = loss_func(y, labels.reshape([100,1]))
            losslist.append(loss)
            # print('{} epoch, loss:{}'.format(epoch, loss))
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
        avgloss = sum(losslist)/ len(losslist)
        print('{} epoch, loss:{}'.format(epoch, avgloss))
    torch.save(spNet.state_dict(), 'car.pkl')
    
    # predict
    spNet.load_state_dict(torch.load('./car.pkl'))
    spNet.eval()
    print(testx)
    prediction = spNet(testx)
    print(prediction)
    list = [float(i) for i in prediction]
    # print(list)
    with open('./test_predict.txt', 'w') as f:
        print('y',file=f)
        for element in list:
            print(element,file=f)
# Out:
# (10000, 3)
# 0 epoch, loss:0.11790876090526581
# 1 epoch, loss:0.10844209790229797
# 2 epoch, loss:0.1000729352235794
# 3 epoch, loss:0.09265971928834915
# 4 epoch, loss:0.08611024916172028
# 5 epoch, loss:0.08036361634731293
# 6 epoch, loss:0.07537496089935303
# 7 epoch, loss:0.07108525931835175
# 8 epoch, loss:0.06742271035909653
# 9 epoch, loss:0.06430434435606003
# 10 epoch, loss:0.061644259840250015
# 11 epoch, loss:0.05936196818947792
# 12 epoch, loss:0.057387951761484146
# 13 epoch, loss:0.05566376447677612
# 14 epoch, loss:0.05414288863539696
# 15 epoch, loss:0.0527888685464859
# 16 epoch, loss:0.051572903990745544
# 17 epoch, loss:0.05047254636883736
# 18 epoch, loss:0.049469880759716034
# 19 epoch, loss:0.0485503263771534
# 20 epoch, loss:0.047702062875032425
# 21 epoch, loss:0.04691537097096443
# 22 epoch, loss:0.04618211090564728
# 23 epoch, loss:0.04549544304609299
# 24 epoch, loss:0.044849563390016556
# 25 epoch, loss:0.044239506125450134
# 26 epoch, loss:0.043661028146743774
# 27 epoch, loss:0.043110113590955734
# 28 epoch, loss:0.042583636939525604
# 29 epoch, loss:0.042078543454408646
# 30 epoch, loss:0.04159216955304146
# 31 epoch, loss:0.04112202674150467
# 32 epoch, loss:0.040665868669748306
# 33 epoch, loss:0.04022138565778732
# 34 epoch, loss:0.03978656977415085
# 35 epoch, loss:0.039359405636787415
# 36 epoch, loss:0.0389377661049366
# 37 epoch, loss:0.03851952776312828
# 38 epoch, loss:0.03810244798660278
# 39 epoch, loss:0.03768443688750267
# 40 epoch, loss:0.037263136357069016
# 41 epoch, loss:0.03683646768331528
# 42 epoch, loss:0.03640257194638252
# 43 epoch, loss:0.035959988832473755
# 44 epoch, loss:0.03550763800740242
# 45 epoch, loss:0.03504501283168793
# 46 epoch, loss:0.03457218408584595
# 47 epoch, loss:0.034089576452970505
# 48 epoch, loss:0.03359793871641159
# 49 epoch, loss:0.033098213374614716
# 50 epoch, loss:0.03259057179093361
# 51 epoch, loss:0.03207490220665932
# 52 epoch, loss:0.03155263513326645
# 53 epoch, loss:0.031027600169181824
# 54 epoch, loss:0.03050537407398224
# 55 epoch, loss:0.029990943148732185
# 56 epoch, loss:0.029487663879990578
# 57 epoch, loss:0.028997352346777916
# 58 epoch, loss:0.02852080948650837
# 59 epoch, loss:0.028058331459760666
# 60 epoch, loss:0.027609847486019135
# 61 epoch, loss:0.027175091207027435
# 62 epoch, loss:0.026753656566143036
# 63 epoch, loss:0.02634507603943348
# 64 epoch, loss:0.02594885788857937
# 65 epoch, loss:0.025564489886164665
# 66 epoch, loss:0.025191470980644226
# 67 epoch, loss:0.024829329922795296
# 68 epoch, loss:0.024477586150169373
# 69 epoch, loss:0.02413582243025303
# 70 epoch, loss:0.023803628981113434
# 71 epoch, loss:0.023480629548430443
# 72 epoch, loss:0.02316642738878727
# 73 epoch, loss:0.02286067232489586
# 74 epoch, loss:0.022563055157661438
# 75 epoch, loss:0.022273235023021698
# 76 epoch, loss:0.02199091576039791
# 77 epoch, loss:0.021715829148888588
# 78 epoch, loss:0.02144768461585045
# 79 epoch, loss:0.021186213940382004
# 80 epoch, loss:0.02093118615448475
# 81 epoch, loss:0.02068236656486988
# 82 epoch, loss:0.020439540967345238
# 83 epoch, loss:0.020202474668622017
# 84 epoch, loss:0.01997099630534649
# 85 epoch, loss:0.019744880497455597
# 86 epoch, loss:0.01952395774424076
# 87 epoch, loss:0.019308043643832207
# 88 epoch, loss:0.019096970558166504
# 89 epoch, loss:0.018890591338276863
# 90 epoch, loss:0.018688742071390152
# 91 epoch, loss:0.018491283059120178
# 92 epoch, loss:0.018298054113984108
# 93 epoch, loss:0.01810893416404724
# 94 epoch, loss:0.01792379841208458
# 95 epoch, loss:0.017742497846484184
# 96 epoch, loss:0.017564935609698296
# 97 epoch, loss:0.017390988767147064
# 98 epoch, loss:0.017220554873347282
# 99 epoch, loss:0.017053531482815742
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-04c071f4cd94> in <module>
#      64     spNet.load_state_dict(torch.load('./car.pkl'))
#      65     spNet.eval()
# ---> 66     print(testx)
#      67     prediction = spNet(testx)
#      68     print(prediction)
#
# NameError: name 'testx' is not defined
